# %%
import pickle

# %%
#now going to next phase deployment
#model creation file and deployment file should be in same folder
#getting predicted value for 13 years
loaded_model=pickle.load(open("finalised_model_linear.sav",'rb'))
result=loaded_model.predict([[13]])
# Out:
# C:\anaconda\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
result
# Out:
# array([[148460.78806172]])

# %%
#checking for 0 years exp which is fresher. it has origin value which is bias value
#y=mx+c(y=0+bias) as x is 0
result=loaded_model.predict([[0]])
# Out:
# C:\anaconda\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
result
# Out:
# array([[26777.3913412]])
